# %%
from crypto_analyzer import CryptoAnalyzer

# %%
import pandas as pd
# Load your data
path = '/Users/fsl/Documents/GitHub/CPSC540ParlettPelleriti/FinalProject/data.csv'
data = pd.read_csv(path)  # or your data source

# Initialize analyzer
analyzer = CryptoAnalyzer(data)

# Run full analysis
analyzer.prepare_data()
analyzer.analyze_correlations()
analyzer.analyze_lagged_relationships()
analyzer.analyze_combined_effects()

# Generate visualizations
plots = analyzer.visualize_results()

# Get summary report
report = analyzer.generate_report()

# %%
data
# Out:
#      Unnamed: 0  Year  Week  BTC_Weekly_Avg_Price  BTC_Close_Price  \
# 0             1  2018    46           5838.651437      5623.540039
# 1             2  2018    47           4361.330008      4009.969971
# 2             3  2018    48           4072.562116      4139.877930
# 3             4  2018    49           3662.343959      3614.234375
# 4             5  2018    50           3351.422468      3252.839111
# ..          ...   ...   ...                   ...              ...
# 223         224  2023     7          23642.106306     24327.642580
# 224         225  2023     8          23905.221819     23561.212890
# 225         226  2023     9          22991.969308     22435.513670
# 226         227  2023    10          21387.747489     22163.949220
# 227         228  2023    11          25828.691685     28038.675780
#
#      Weekly_Avg_Fear_Greed  BTC_Weekly_Avg_Volume  BTC_Open_Price  \
# 0                36.857143           5.281829e+09     6411.270020
# ...
